# %%
# %gui tk
# %matplotlib notebook

# %%
from annotator import MatplotlibAnnotator
import matplotlib.pyplot as plt

# %%
x = MatplotlibAnnotator()

# %%
img = plt.imread("data/baseball/ball_frame_0.jpg")

# %%
x.plot_annotate(img, ["Home Plate", "Right batter's box", "Left batter's box", "Pitcher's mound"])
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
x.get_annotations()
# Out:
# {'Home Plate': [651.8354838709677, 403.21612903225787],
#  "Right batter's box": [364.4548387096774, 627.8354838709677],
#  "Left batter's box": [481.71935483870965, 404.86774193548376],
#  "Pitcher's mound": [815.3451612903225, 423.0354838709676]}
