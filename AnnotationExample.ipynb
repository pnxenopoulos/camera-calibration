# %%
# %gui tk
# %matplotlib notebook

# %%
from annotator import MatplotlibAnnotator
import matplotlib.pyplot as plt

# %%
x = MatplotlibAnnotator()

# %%
img = plt.imread("data/baseball/ball_frame_0.jpg")

# %%
x.plot_annotate(img, ["Home Plate", "Right batter's box", "Left batter's box", "Pitcher's mound"])
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
x.get_annotations()
# Out:
# {'Home Plate': [673.8810483870968, 406.18558467741934],
#  "Right batter's box": [488.90040322580643, 434.263004032258],
#  "Left batter's box": [806.0100806451612, 430.9597782258064],
#  "Pitcher's mound": [346.8616935483871, 629.1533266129031]}
