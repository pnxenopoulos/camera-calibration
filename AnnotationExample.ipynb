# %%
# %gui tk
# %matplotlib notebook

# %%
from annotator import MatplotlibAnnotator
import matplotlib.pyplot as plt

# %%
x = MatplotlibAnnotator()

# %%
img = plt.imread("data/baseball/ball_frame_0.jpg")

# %%
x.plot_annotate(img, ["Home Plate", "Pitcher", "Batter"])
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
x.get_annotations()
# Out:
# {'Home Plate': [662.3197580645162, 434.263004032258],
#  'Pitcher': [422.83588709677423, 321.9533266129032],
#  'Batter': [465.77782258064514, 97.33397177419351]}
